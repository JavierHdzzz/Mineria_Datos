# %% [markdown]
# # Lectura de Base de Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("homicidios.csv", na_values="Unknown")
# Out:
# C:\Users\86453\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # Cantidad de Filas y Columnas en nuestra base de Datos

# %%
df.shape
# Out:
# (638454, 24)

# %% [markdown]
# # Visualizar los primeros datos

# %%
df.head(10)
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 5          6     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 6          7     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 7          8     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 8          9     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 9         10     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type  ... Victim Ethnicity  \
# 0  1980  January         1  Murder or Manslaughter  ...          Unknown
# ...

# %% [markdown]
# # Visualizar los ultimos datos

# %%
df.tail(10)
# Out:
#         Record ID Agency Code      Agency Name       Agency Type        City  \
# 638444     638445     WY01101         Cheyenne  Municipal Police     Laramie
# 638445     638446     WY01200   Lincoln County           Sheriff     Lincoln
# 638446     638447     WY01300   Natrona County           Sheriff     Natrona
# 638447     638448     WY01301           Casper  Municipal Police     Natrona
# 638448     638449     WY01301           Casper  Municipal Police     Natrona
# 638449     638450     WY01500      Park County           Sheriff        Park
# 638450     638451     WY01700  Sheridan County           Sheriff    Sheridan
# 638451     638452     WY01701         Sheridan  Municipal Police    Sheridan
# 638452     638453     WY01800  Sublette County           Sheriff    Sublette
# 638453     638454     WY01902     Rock Springs  Municipal Police  Sweetwater
#
#           State  Year      Month  Incident              Crime Type  ...  \
# ...

# %% [markdown]
# # Visualización de Datos

# %%
x =("Victim Sex","Perpetrator Ethnicity","Perpetrator Race","Weapon")
for i in x:
   sns.countplot(x = i, data = df, color = "blue")
   plt.xticks(rotation=50)
   plt.show()

# %% [markdown]
# # Mostrar los datos de las columnas

# %%
df.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %% [markdown]
# # Cambiar el nombre de las columnas

# %%
df.rename(columns = {'City':'Ciudad', 'State':'Estado', 'Perpetrator Sex':'Perpetrator_Sex', 'Victim Count':'Victim_Count'}, inplace=True)
df.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'Ciudad',
#        'Estado', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator_Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim_Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %% [markdown]
# # Tipos de dato en cada columna

# %%
df.dtypes
# Out:
# Record ID                 int64
# Agency Code              object
# Agency Name              object
# Agency Type              object
# City                     object
# State                    object
# Year                      int64
# Month                    object
# Incident                  int64
# Crime Type               object
# Crime Solved             object
# Victim Sex               object
# Victim Age                int64
# Victim Race              object
# Victim Ethnicity         object
# Perpetrator Sex          object
# Perpetrator Age          object
# Perpetrator Race         object
# Perpetrator Ethnicity    object
# Relationship             object
# Weapon                   object
# Victim Count              int64
# Perpetrator Count         int64
# Record Source            object
# dtype: object

# %% [markdown]
# # Tipo de datos que contiene una columna en especifico

# %%
df['Year'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # Extraer valores unicos de una columna

# %%
df.Perpetrator_Sex.unique()
# Out:
# array(['Male', 'Unknown', 'Female'], dtype=object)

# %% [markdown]
# # Agrupar todos los valores dentro de la clase en la que estan etiquetados

# %%
clase_1 = df[df['Perpetrator_Sex']=='Male']
clase_2 = df[df['Perpetrator_Sex']=='Female']
clase_3 = df[df['Perpetrator_Sex']=='Unknown']

clase_1.to_csv('Solo_clase1.csv', index=False)
clase_1
# Out:
#         Record ID Agency Code      Agency Name       Agency Type     Ciudad  \
# 0               1     AK00101        Anchorage  Municipal Police  Anchorage
# 1               2     AK00101        Anchorage  Municipal Police  Anchorage
# 3               4     AK00101        Anchorage  Municipal Police  Anchorage
# 5               6     AK00101        Anchorage  Municipal Police  Anchorage
# 6               7     AK00101        Anchorage  Municipal Police  Anchorage
# ...           ...         ...              ...               ...        ...
# 638446     638447     WY01300   Natrona County           Sheriff    Natrona
# 638447     638448     WY01301           Casper  Municipal Police    Natrona
# 638448     638449     WY01301           Casper  Municipal Police    Natrona
# 638450     638451     WY01700  Sheridan County           Sheriff   Sheridan
# 638452     638453     WY01800  Sublette County           Sheriff   Sublette
#
# ...

# %%
print(df.Year.unique())
class_1 = df[df['Year']==1980]
class_2 = df[df['Year']==1981]
class_3 = df[df['Year']==1982]
class_4 = df[df['Year']==1983]
class_5 = df[df['Year']==1984]
# Out:
# [1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993
#  1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014]

# %% [markdown]
# # Si se quiere encontrar un valor dentro de un data frame, dependiendo de los valores de otra columna se utiliza

# %%
clase_1_vs_Year = df.loc[df.Perpetrator_Sex == 'Female'].Year
print(clase_1_vs_Year)
# Out:
# 15        1980
# 27        1980
# 28        1980
# 46        1980
# 48        1980
#           ...
# 638433    2014
# 638434    2014
# 638435    2014
# 638451    2014
# 638453    2014
# Name: Year, Length: 48548, dtype: int64

# %% [markdown]
# # Suponiendo ahora que solo tengo dos tipos de clase en la columna Nombre_columna, y quiero cambiar los nombres dentro de los datos unicos para poder realizar una clasificacion binaria,

# %%
df.Perpetrator_Sex.replace(to_replace = dict(Clase_1 = 1, Clase_2 = 0, Clase_3 = "NA"), inplace = True)

# %% [markdown]
# # Datos Nulos

# %%
df.isnull().any()
# Out:
# Record ID                False
# Agency Code              False
# Agency Name               True
# Agency Type              False
# City                     False
# State                    False
# Year                     False
# Month                    False
# Incident                 False
# Crime Type               False
# Crime Solved             False
# Victim Sex                True
# Victim Age               False
# Victim Race               True
# Victim Ethnicity          True
# Perpetrator Sex           True
# Perpetrator Age          False
# Perpetrator Race          True
# Perpetrator Ethnicity     True
# Relationship              True
# Weapon                    True
# Victim Count             False
# Perpetrator Count        False
# Record Source            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Record ID                     0
# Agency Code                   0
# Agency Name                  47
# Agency Type                   0
# City                          0
# State                         0
# Year                          0
# Month                         0
# Incident                      0
# Crime Type                    0
# Crime Solved                  0
# Victim Sex                  984
# Victim Age                    0
# Victim Race                6676
# Victim Ethnicity         368303
# Perpetrator Sex          190365
# Perpetrator Age               0
# Perpetrator Race         196047
# Perpetrator Ethnicity    446410
# Relationship             273013
# Weapon                    33192
# Victim Count                  0
# Perpetrator Count             0
# Record Source                 0
# dtype: int64

# %% [markdown]
# # Realizar una tarea de preprocesamiento no mencionada en esta práctica.

# %%
suma = (class_1["Victim Count"].sum(),class_2["Victim Count"].sum(),class_3["Victim Count"].sum(),class_4["Victim Count"].sum(),class_5["Victim Count"].sum())
years= ["1980","1981","1982","1983","1984"]
plt.bar(years,suma)
plt.title("ASESINATOS POR ANO")
plt.figure(figsize=(15,15))
plt.show()

print(clase_1.Weapon.value_counts())
states = df.State.unique()
print(clase_1.Estado.value_counts().sort_values(ascending=False))
# Out:
# Handgun          199776
# Knife             61015
# Blunt Object      45782
# Shotgun           24307
# Firearm           23103
# Rifle             18486
# Unknown           14722
# Strangulation      4019
# Fire               3132
# Suffocation        1927
# Gun                1240
# Drugs               827
# Drowning            492
# Explosives          355
# Poison              221
# Fall                137
# Name: Weapon, dtype: int64
# California              58199
# Texas                   42198
# New York                24317
# Florida                 23610
# Michigan                16773
# Pennsylvania            16722
# North Carolina          14386
# Illinois                14069
# Georgia                 13131
# Louisiana               11988
# Ohio                    11957
# Tennessee               11075
# Virginia                10761
# Maryland                 9371
# South Carolina           9262
# Arizona                  8454
# Missouri                 8345
# ...
